# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 48.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.2/112.6 GB disk)

# %%
# %pwd
# Out:
# '/content'

# %%
# !mkdir LogoDetection

# %%
path="/content/LogoDetection"

# %%
import os
os.chdir("/content/LogoDetection")
# %pwd
# Out:
# '/content/LogoDetection'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uJQDFbQzfr7uWS0WwWlE")
project = rf.workspace("testspace-6ia9d").project("logo-detection-wrdch")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to logo-detection-1 in yolov8:: 100%|██████████| 16138/16138 [00:02<00:00, 6544.12it/s]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-54157665-992f-497a-8dcc-c5632fde58fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-54157665-992f-497a-8dcc-c5632fde58fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/last.pt')

# Start a new training run and continue training till 80 epochs
model.train(epochs=50, data='/content/logo-detection-1/data.yaml')
# Out:
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO('/content/runs/detect/train/weights/best.pt')

# Run prediction
results = model.predict(
    source='/content/logo-detection-1/train/images',  # or wherever your images are
    save=True,
    conf=0.25
)
# Out:
# Streaming output truncated to the last 5000 lines.
# image 1211/6650 /content/logo-detection-1/train/images/Belgalogos_07704356_jpg.rf.06ed38b18a8fdd815873efd74571e013.jpg: 640x640 4 adidas1s, 7.5ms
# image 1212/6650 /content/logo-detection-1/train/images/Belgalogos_07704356_jpg.rf.2b8008de83389faec2fb838c737d329d.jpg: 640x640 4 adidas1s, 7.5ms
# image 1213/6650 /content/logo-detection-1/train/images/Belgalogos_07704356_jpg.rf.4f0533af82936b9e438d8702cbeed580.jpg: 640x640 3 adidas1s, 1 mercedesbenz, 8.0ms
# image 1214/6650 /content/logo-detection-1/train/images/Belgalogos_07704356_jpg.rf.cf9fe033f9fb4d8cf45bfa040690d444.jpg: 640x640 2 adidas1s, 7.5ms
# image 1215/6650 /content/logo-detection-1/train/images/Belgalogos_07705338_jpg.rf.6f959cc8a55483c8ab794fc23dacb8bb.jpg: 640x640 1 adidas1, 10.0ms
# image 1216/6650 /content/logo-detection-1/train/images/Belgalogos_07705338_jpg.rf.af025965a38f284df5212e091d320715.jpg: 640x640 1 adidas1, 7.6ms
# ...

# %%
# !zip -r /content/train2_results.zip /content/runs/detect/train
# Out:
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/val_batch1_labels.jpg (deflated 8%)
#   adding: content/runs/detect/train/labels_correlogram.jpg (deflated 29%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 4%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 9%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 9%)
#   adding: content/runs/detect/train/BoxF1_curve.png (deflated 9%)
#   adding: content/runs/detect/train/train_batch16641.jpg (deflated 8%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 8%)
#   adding: content/runs/detect/train/val_batch2_pred.jpg (deflated 6%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 19%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 3%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 4%)
# ...

# %%
from google.colab import files
files.download('/content/train2_results.zip')
